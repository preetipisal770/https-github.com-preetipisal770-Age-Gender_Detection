# %%
#OpenCv

# %%
pip install opencv--python
# Out:
# Requirement already satisfied: opencv--python in c:\users\preet\appdata\local\programs\python\python311\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\preet\appdata\local\programs\python\python311\lib\site-packages (from opencv--python) (1.25.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
import cv2

# %%
from matplotlib import pyplot as plt

# %%
#plotting
img1=cv2.imread("Resources\Data\plant2.png",0)

# %%
plt.imshow(img1)

# %%
#Arithmetic Operation
img2=cv2.imread("Resources\Data\plant3.png",0)

# %%
img2_resized = cv2.resize(img2, (360, 543))

# %% [markdown]
# #Addition

# %%
result = img1 + img2_resized

# %%
plt.imshow(result)

# %% [markdown]
# #Subtraction

# %% [markdown]
# result = img1 - img2_resized

# %%
plt.imshow(result)

# %% [markdown]
# #Multiplication

# %%
result = img1 * img2_resized

# %%
plt.imshow(result)

# %% [markdown]
# #Division

# %%
result = img1 /img2_resized

# %%
plt.imshow(result)

# %%
#Bluring img
img1=cv2.imread("Resources\Data\elephant.jpg")

# %%
img=cv2.cvtColor(img1,cv2.COLOR_BGR2HSV)
figure_size=7

# %%
result=cv2.blur(img,(figure_size,figure_size))
plt.figure(figsize=(11,6))
plt.subplot(121),plt.imshow(cv2.cvtColor(img,cv2.COLOR_HSV2RGB)),plt.title("Original")
plt.xticks([]),plt.yticks([])
plt.subplot(122),plt.imshow(cv2.cvtColor(result,cv2.COLOR_HSV2RGB)),plt.title("Blurred")
plt.xticks([]),plt.yticks([])
plt.show()

# %%
#Zoom an image
img1=cv2.imread("Resources\Data\plant2.png")

# %%
(height,width)=img1.shape[0:2]
zoom=cv2.resize(img1,None,fx=1.5,fy=1.5,interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
zoom=cv2.resize(img1,(int(width*2),int(height*2)),interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
#rotate image
m=cv2.getRotationMatrix2D((width/2,height/2),30,1)
rotate=cv2.warpAffine(img1,m,(height,width))
plt.imshow(rotate)

# %%
#Translate the image
import numpy as np

# %%
np.float32([[1,0,50],[0,1,100]])
dst=cv2.warpAffine(img,m,(height,width))#50 co-ordinate right,100 co-ordinate downward
plt.imshow(dst)
